# %% [markdown]
# # Create a dataset that we can analyse, which includes the results of the BTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dropbox
import io

# Connect to dropbox for raw data DO NOT COMMIT TOKEN
access_token = 'XXX'
dbx = dropbox.Dropbox(access_token)

# %% [markdown]
# ## Load in outputs and original data

# %%
# Load tdm
md, response = dbx.files_download("/ClassifyingESTC/results/BTM19_NONUMBERS_DEDUPED_AdStpwds__TOPIC_DOC_MAT.csv")
tdm = pd.read_csv(io.BytesIO(response.content), encoding = "ISO-8859-1")

tdm.head()
# Out:
#               0         1         2             3             4         5  \
# 0  1.387308e-01  0.695160  0.021509  2.122421e-06  1.160653e-06  0.001511
# 1  3.118734e-02  0.046276  0.289836  1.397354e-04  3.617359e-07  0.024720
# 2  1.798107e-01  0.002929  0.017221  1.416502e-06  7.746189e-07  0.019313
# 3  4.027834e-02  0.015272  0.014795  6.765009e-07  5.619319e-02  0.128679
# 4  1.863697e-07  0.000003  0.000001  2.308252e-05  1.262276e-05  0.000064
#
#               6         7         8         9  ...     94680     94681  \
# 0  1.595839e-08  0.012673  0.004342  0.002427  ...  0.004498  0.313115
# 1  1.963455e-03  0.043833  0.164854  0.031784  ...  0.158796  0.056213
# 2  3.368735e-05  0.021223  0.006268  0.058344  ...  0.017532  0.081998
# 3  5.086580e-09  0.038688  0.256291  0.074795  ...  0.279345  0.025930
# 4  1.735564e-07  0.000005  0.000067  0.000706  ...  0.000003  0.000003
#
#       94682         94683         94684         94685     94686     94687  \
# 0  0.046310  1.074485e-02  9.475545e-04  4.411096e-02  0.038660  0.047853
# 1  0.064663  8.404406e-02  3.723422e-02  1.438186e-01  0.085040  0.002602
# 2  0.018546  1.613170e-02  3.079085e-02  1.382835e-02  0.078040  0.008830
# 3  0.026698  2.473841e-02  4.127700e-02  2.492005e-02  0.136009  0.098291
# 4  0.000056  1.599264e-10  1.821761e-10  1.316764e-07  0.002013  0.000105
#
#       94688         94689
# 0  0.081622  2.592158e-03
# 1  0.130082  1.110681e-01
# 2  0.021913  1.356243e-02
# 3  0.011968  2.658302e-03
# 4  0.000128  2.346361e-08
#
# [5 rows x 94690 columns]

# %%
# Load processed data
md, response = dbx.files_download("/ClassifyingESTC/intermediate_output/estc_btm_prepped.csv")
processed = pd.read_csv(io.BytesIO(response.content), encoding = "ISO-8859-1")

processed.head()
# Out:
#    system_number    date  pages      format  \
# 0        6172522  1600.0    1.0   broadside
# 1        6180391  1600.0  584.0      octavo
# 2        6206783  1600.0  576.0      octavo
# 3        6205242  1600.0    1.0  half_sheet
# 4        6205278  1600.0    1.0  half_sheet
#
#                                                title  \
# 0  By the Queene. Whereas the Earle of Essex : ac...
# 1  Essayes : By Sir William Corne-Waleys the youn...
# 2  The booke of common prayer, and administration...
# 3       Immortalitas animarum naturaliter innotescit
# 4                  Plantæ viuaciores sunt animalibus
#
#                                          clean_title
# 0  queen wherea earl essex accompani earl rutland...
# 1        essay sir william cornewaley younger knight
# 2  book common prayer administr sacrament rite ce...
# 3          immortalita animarum naturalit innotescit
# 4                      plant viuacior sunt animalibu

# %%
# Must equal TRUE!
processed.shape[0] == tdm.shape[1]
# Out:
# True

# %% [markdown]
# ## Topic prevalence and system number

# %%
transposed = pd.DataFrame(tdm.T)
transposed['system_number'] = processed['system_number'].tolist()
transposed.head()

# Save to dropbox
df_string = transposed.to_csv(index=False)
db_bytes = bytes(df_string, "ISO-8859-1")
dbx.files_upload(
    f=db_bytes,
    path="/ClassifyingESTC/results/prevalence_with_system_number.csv",
    mode=dropbox.files.WriteMode.overwrite
)
# Out:
# FileMetadata(client_modified=datetime.datetime(2025, 3, 8, 15, 29, 43), content_hash='057c95c09ce977c8187eceac44f180fab89289971288f201c66be25c967d91c2', export_info=NOT_SET, file_lock_info=NOT_SET, has_explicit_shared_members=NOT_SET, id='id:wwr8ZQ2NbWIAAAAAAAAiiw', is_downloadable=True, media_info=NOT_SET, name='prevalence_with_system_number.csv', parent_shared_folder_id='3961543809', path_display='/ClassifyingESTC/Results/prevalence_with_system_number.csv', path_lower='/classifyingestc/results/prevalence_with_system_number.csv', preview_url=NOT_SET, property_groups=NOT_SET, rev='62fd6688a98e2ec205c81', server_modified=datetime.datetime(2025, 3, 8, 15, 29, 43), sharing_info=FileSharingInfo(modified_by='dbid:AAAZrg3IGwGPrkL3cB_LnN3I7Tdm7nHQJgk', parent_shared_folder_id='3961543809', read_only=False), size=35318563, symlink_info=NOT_SET)

# %% [markdown]
# ## Document and top topic

# %%
# Returns most prev topic for each doc
most_prev_topic = tdm.idxmax(axis = 0).to_list()

# Add to dataframe three times
processed['top_topic_no'] = most_prev_topic

processed.head(3)
# Out:
#    system_number    date  pages     format  \
# 0        6172522  1600.0    1.0  broadside
# 1        6180391  1600.0  584.0     octavo
# 2        6206783  1600.0  576.0     octavo
#
#                                                title  \
# 0  By the Queene. Whereas the Earle of Essex : ac...
# 1  Essayes : By Sir William Corne-Waleys the youn...
# 2  The booke of common prayer, and administration...
#
#                                          clean_title  top_topic_no
# 0  queen wherea earl essex accompani earl rutland...             2
# 1        essay sir william cornewaley younger knight             0
# 2  book common prayer administr sacrament rite ce...             7

# %% [markdown]
# ## Full dataset with topic (And slim version while I'm there)

# %%
# load original data
md, response = dbx.files_download("/ClassifyingESTC/input_files/estc_with_pages.csv")
raw = pd.read_csv(io.BytesIO(response.content), encoding = "ISO-8859-1")

raw = raw.set_index('system_number')

raw.head(3)
# Out:
#               citation_number                  name   name_dates name_type  \
# system_number
# 6180992               S109298        Lefèvre, Raoul  active 1460    person
# 6178187               S106478  Cessolis, Jacobus de          NaN    person
# 6194414               S123061        Lefèvre, Raoul  active 1460    person
#
#               role                                          all_names  \
# system_number
# 6180992        NaN  Mansion, Colard, printer [person] ; Caxton, Wi...
# 6178187        NaN  Mansion, Colard, printer [person] ; Caxton, Wi...
# 6194414        NaN  Caxton, William, approximately 1422-1491 or 14...
#
#                                                            title    date  \
# system_number
# 6180992        hEre begynneth the volume intituled and named ...  1473.0
# 6178187        [T] o the right noble, right excellent [and] v...  1474.0
# 6194414        Cy commence le volume intitule le recueil des ...  1474.0
#
#                                                        publisher  country  \
# system_number
# 6180992        Printed by William Caxton and, probably, Colar...  Belgium
# 6178187            Printed by William Caxton and Colard Mansion,  Belgium
# 6194414        printed by William Caxton and, probably, Colar...  Belgium
#
#                  city                                              place  \
# system_number
# 6180992        Bruges  [Bruges : Printed by William Caxton and, proba...
# 6178187        Bruges  [Bruges : Printed by William Caxton and Colard...
# 6194414        Bruges  [Ghent?] : [David Aubert?, for William Caxton]...
#
#               physical_description  pages format language
# system_number
# 6180992             [704] p. ; 2?.  704.0  folio      eng
# 6178187             [148] p. ; 2?.  148.0  folio      eng
# 6194414             [572] p. ; 2?.  572.0  folio      fre

# %%
# Join
processed = processed[['system_number','top_topic_no']]

final_results = raw.merge(processed.set_index('system_number'), how = 'inner', left_index = True, right_index = True)

final_results.head(20)
# Out:
#               citation_number  \
# system_number
# 6172522               S100840
# 6180391               S108699
# 6206783                S96096
# 6205242                S91321
# 6205278                S91286
# 6209331               T301210
# 6476680               R477519
# 6478143               R479028
# 6479648               R491169
# 6197728                 S2474
# 6197755                 S2501
# 6197757                 S2503
# 6197758                 S2504
# 6197818                 S2576
# 6197922                 S2696
# 6206786               S126808
# 6144268                R41273
# 6171531               S125599
# 6171546               S125585
# 6171547               S125584
#
#                                                             name  \
# system_number
# 6172522        England and Wales, Sovereign (1558-1603 : Eliz...
# 6180391                                 Cornwallis, William, Sir
# 6206783                                        Church of England
# 6205242                                  University of Cambridge
# 6205278                                  University of Cambridge
# 6209331                                              White, John
# 6476680                                                      NaN
# 6478143                                              Capon, John
# 6479648                                             Biddle, John
# 6197728                                           Watson, Robert
# 6197755                                                      NaN
# 6197757                                                      NaN
# 6197758                                                      NaN
# 6197818                                                 J. G. E.
# 6197922                                        Greenham, Richard
# 6206786                                                      NaN
# 6144268                                                      NaN
# 6171531                                               Dade, John
# 6171546                                         Younger, William
# 6171547                                           Wright, Thomas
#
#                                           name_dates     name_type role  \
# system_number
# 6172522                                          NaN  organisation  NaN
# 6180391                      approximately 1579-1614        person  NaN
# 6206783                                          NaN  organisation  NaN
# 6205242                                          NaN  organisation  NaN
# 6205278                                          NaN  organisation  NaN
# 6209331                                        -1671        person  NaN
# 6476680                                          NaN           NaN  NaN
# 6478143                                          NaN        person  NaN
# 6479648                                    1615-1662        person  NaN
# 6197728                                          NaN        person  NaN
# 6197755                                          NaN           NaN  NaN
# 6197757                                          NaN           NaN  NaN
# 6197758                                          NaN           NaN  NaN
# 6197818                                          NaN        person  NaN
# 6197922        approximately 1535-approximately 1594        person  NaN
# 6206786                                          NaN           NaN  NaN
# 6144268                                          NaN           NaN  NaN
# 6171531                             active 1589-1614        person  NaN
# 6171546                                1572 or 1573-        person  NaN
# 6171547                                        -1624        person  NaN
#
#                                                        all_names  \
# system_number
# 6172522        Barker, Robert, -1645, printer [person] ; Engl...
# 6180391        Olney, Henry, editor [person] ; Mattes, Edmund...
# 6206783        Church of England [organisation] ; Barker, Rob...
# 6205242                   University of Cambridge [organisation]
# 6205278                   University of Cambridge [organisation]
# 6209331                              White, John, -1671 [person]
# 6476680        Bellamie, John, -1654, bookseller [person] ; S...
# 6478143                                     Capon, John [person]
# 6479648                         Biddle, John, 1615-1662 [person]
# 6197728                                  Watson, Robert [person]
# 6197755                                                      NaN
# 6197757        Augustine, of Hippo, Saint [person] ; Rogers, ...
# 6197758        Augustine, of Hippo, Saint [person] ; Rogers, ...
# 6197818                                        J. G. E. [person]
# 6197922        Greenham, Richard, approximately 1535-approxim...
# 6206786                                                      NaN
# 6144268                                                      NaN
# 6171531                    Dade, John, active 1589-1614 [person]
# 6171546                 Younger, William, 1572 or 1573- [person]
# 6171547                           Wright, Thomas, -1624 [person]
#
#                                                            title    date  \
# system_number
# 6172522        By the Queene. Whereas the Earle of Essex : ac...  1600.0
# 6180391        Essayes : By Sir William Corne-Waleys the youn...  1600.0
# 6206783        The booke of common prayer, and administration...  1600.0
# 6205242             Immortalitas animarum naturaliter innotescit  1600.0
# 6205278                        Plantæ viuaciores sunt animalibus  1600.0
# 6209331        Art's treasury, or, A profitable and pleasing ...  1600.0
# 6476680        The cobler of Pragve : with all his merry conc...  1600.0
# 6478143        The nevv booke of Mr. Iohn Capons wits : dedic...  1600.0
# 6479648        A brief scripture-catechism for children : Whe...  1600.0
# 6197728        A doble almanacke or kalender drawne for this ...  1600.0
# 6197755        [The Poor people's complaint bewailing the dea...  1600.0
# 6197757        S. Augustines manuel : conteining speciall, an...  1600.0
# 6197758        A Right Christian treatise, entituled S. Augus...  1600.0
# 6197818                        Englands hope, against Irish hate  1600.0
# 6197922        The second part of the workes ... of Richard G...  1600.0
# 6206786        A dyet for the Christian soule : Constantly to...  1600.0
# 6144268        The Book of subscriptions for insuring of hous...  1600.0
# 6171531        Dade. 1600 : [An almanacke, and] prognosticati...  1600.0
# 6171546        A sermon preached at Great Yarmouth, vpon VVed...  1600.0
# 6171547        Certaine articles or forcible reasons : Discou...  1600.0
#
#                                                        publisher   country  \
# system_number
# 6172522        by Robert Barker, printer to the Queenes most ...   England
# 6180391        Printed [by S. Stafford and R. Read] for Edmun...   England
# 6206783        Imprinted at London by Robert Barker, printer ...   England
# 6205242                                                    s.n.,   England
# 6205278                                                    s.n.,   England
# 6209331                                                  [s.n.],   England
# 6476680                                                    s.n.,   England
# 6478143                                                    s.n.,   England
# 6479648                                                  [s.n.],   England
# 6197728                   By Richard Watkins and Iames Robertes,  Michigan
# 6197755                                                    s.n.,   England
# 6197757        By Peter Short, dwelling on Bredstreet hil, at...  Michigan
# 6197758        By Peter Short, dwelling on Bredstreet hil, at...  Michigan
# 6197818                      Printed by VV.VV. for Thomas Heyes,  Michigan
# 6197922                               F. Kyngston for R. Dexter,  Michigan
# 6206786               imprinted by [Iohn Windet for] Iohn Wolfe,   England
# 6144268        Printed by S. Roycroft, printer to the honoura...   England
# 6171531                 by Richard VVatkins and Iames Robertes.,   England
# 6171546        by Simon Stafford, dwelling on Adling hill, ne...   England
# 6171547        Printed at Anwerpe [sic] [By the English secre...   England
#
#                                 city  \
# system_number
# 6172522          Imprinted at London
# 6180391                       London
# 6206783                       London
# 6205242                    Cambridge
# 6205278                    Cambridge
# 6209331                      England
# 6476680                       London
# 6478143                       London
# 6479648                       London
# 6197728          Imprinted at London
# 6197755                       London
# 6197757          Imprinted at London
# 6197758          Imprinted at London
# 6197818                    At London
# 6197922                       London
# 6206786                       London
# 6144268                       London
# 6171531          Imprinted at London
# 6171546          Imprinted at London
# 6171547        Antwerp, i.e. England
#
#                                                            place  \
# system_number
# 6172522        Imprinted at London : by Robert Barker, printe...
# 6180391        [London] : Printed [by S. Stafford and R. Read...
# 6206783        [London] : Imprinted at London by Robert Barke...
# 6205242               [Cambridge : s.n., between 1600 and 1607?]
# 6205278               [Cambridge : s.n., between 1600 and 1607?]
# 6209331                            [England?] : [s.n.], [16--?].
# 6476680        [London] : [William Sheffard and John Bellamy]...
# 6478143                                   [London? : s.n., 16--]
# 6479648               London : [s.n.], printed in the year 16--.
# 6197728        Imprinted at London : By Richard Watkins and I...
# 6197755                               [London? : s.n., ca. 1600]
# 6197757        Imprinted at London : By Peter Short, dwelling...
# 6197758        Imprinted at London : By Peter Short, dwelling...
# 6197818        At London : Printed by VV.VV. for Thomas Heyes...
# 6197922               [London : F. Kyngston for R. Dexter, 1600]
# 6206786        London : imprinted by [Iohn Windet for] Iohn W...
# 6144268        [London] : Printed by S. Roycroft, printer to ...
# 6171531        Imprinted at London : by Richard VVatkins and ...
# 6171546        Imprinted at London : by Simon Stafford, dwell...
# 6171547        [Antwerp, i.e. England] : Printed at Anwerpe [...
#
#                      physical_description  pages      format language  \
# system_number
# 6172522            1 sheet ([1] p.) ; 1?.    1.0   broadside      eng
# 6180391                    [584] p. ; 8?.  584.0      octavo      eng
# 6206783                    [576] p. ; 8?.  576.0      octavo      eng
# 6205242          1 sheet ([1] p.) ; 1/2?.    1.0  half_sheet      eng
# 6205278          1 sheet ([1] p.) ; 1/2?.    1.0  half_sheet      eng
# 6209331               259, [27] p. ; 12?.  286.0        12mo      eng
# 6476680             [2], 39, [1] p. ; 4?.   42.0      quarto      eng
# 6478143                        4 p. ; 8?.    4.0      octavo      eng
# 6479648                  [6], 34 p. ; 8?.   40.0      octavo      eng
# 6197728                           [1+] p.    1.0     unknown      eng
# 6197755                1 broadside : ill.    1.0   broadside      eng
# 6197757                  [14], 96, [6] p.  116.0     unknown      eng
# 6197758                [10], 218, [24] p.  252.0     unknown      eng
# 6197818                           [28] p.   28.0     unknown      eng
# 6197922           [8+], 464 p. 4? in 8's.  472.0      quarto      eng
# 6206786        [2], 20, [2] leaves ; 12?.   48.0        12mo      eng
# 6144268                 1 sheet ([1] p.).    1.0   broadside      eng
# 6171531                     [2+] p. ; 8?.    2.0      octavo      eng
# 6171546                     [87] p. ; 8?.   87.0      octavo      eng
# 6171547                     [44] p. ; 8?.   44.0      octavo      eng
#
#                top_topic_no
# system_number
# 6172522                   2
# 6180391                   0
# 6206783                   7
# 6205242                  13
# 6205278                  13
# 6209331                  16
# 6476680                  10
# 6478143                  14
# 6479648                   3
# 6197728                  18
# 6197755                  10
# 6197757                   7
# 6197758                   7
# 6197818                  10
# 6197922                   7
# 6206786                   7
# 6144268                   9
# 6171531                  18
# 6171546                  15
# 6171547                   1

# %%
# Save to dropbox
df_string = final_results.to_csv(index=False)
db_bytes = bytes(df_string, "ISO-8859-1")
dbx.files_upload(
    f=db_bytes,
    path="/ClassifyingESTC/results/BTM19_RESULTS_NoLabel.csv",
    mode=dropbox.files.WriteMode.overwrite
)
# Out:
# FileMetadata(client_modified=datetime.datetime(2024, 8, 2, 19, 40, 38), content_hash='0621126885fae826dbb6e6146f30e75f1460e0df3e2c89e31810c6318aa9794c', export_info=NOT_SET, file_lock_info=NOT_SET, has_explicit_shared_members=NOT_SET, id='id:wwr8ZQ2NbWIAAAAAAAAifQ', is_downloadable=True, media_info=NOT_SET, name='BTM19_RESULTS_NoLabel.csv', parent_shared_folder_id='3961543809', path_display='/ClassifyingESTC/Results/BTM19_RESULTS_NoLabel.csv', path_lower='/classifyingestc/results/btm19_results_nolabel.csv', preview_url=NOT_SET, property_groups=NOT_SET, rev='61eb8807adaeaec205c81', server_modified=datetime.datetime(2024, 8, 2, 19, 40, 38), sharing_info=FileSharingInfo(modified_by='dbid:AAAZrg3IGwGPrkL3cB_LnN3I7Tdm7nHQJgk', parent_shared_folder_id='3961543809', read_only=False), size=57111548, symlink_info=NOT_SET)

# %%
processed.head()
# Out:
#    system_number  top_topic_no
# 0        6172522             2
# 1        6180391             0
# 2        6206783             7
# 3        6205242            13
# 4        6205278            13

# %%
# Save slim version to dropbox
df_string = processed.to_csv(index=False)
db_bytes = bytes(df_string, "ISO-8859-1")
dbx.files_upload(
    f=db_bytes,
    path="/ClassifyingESTC/results/BTM19_topic_system_number.csv",
    mode=dropbox.files.WriteMode.overwrite
)
# Out:
# FileMetadata(client_modified=datetime.datetime(2025, 1, 19, 15, 7, 8), content_hash='406a6d9f7b188db198c18f239698f525122762e670fe9e11ea221c1059607039', export_info=NOT_SET, file_lock_info=NOT_SET, has_explicit_shared_members=NOT_SET, id='id:wwr8ZQ2NbWIAAAAAAAAigA', is_downloadable=True, media_info=NOT_SET, name='BTM19_topic_system_number.csv', parent_shared_folder_id='3961543809', path_display='/ClassifyingESTC/Results/BTM19_topic_system_number.csv', path_lower='/classifyingestc/results/btm19_topic_system_number.csv', preview_url=NOT_SET, property_groups=NOT_SET, rev='62c107f68cb28ec205c81', server_modified=datetime.datetime(2025, 1, 19, 15, 7, 8), sharing_info=FileSharingInfo(modified_by='dbid:AAAZrg3IGwGPrkL3cB_LnN3I7Tdm7nHQJgk', parent_shared_folder_id='3961543809', read_only=False), size=986956, symlink_info=NOT_SET)
